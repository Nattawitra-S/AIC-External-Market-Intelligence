# %% [markdown]
# # AIC SkillSelect ETL Notebook
# **Australian Centre of English — Market Intelligence Project**
#
# This notebook is used as a control panel for running and checking the SkillSelect ETL workflow.
#
# The main automation logic is stored in:
#
# `ETL/skillselect_csv_exporter.py`
#
# The Jupyter notebook is mainly used to run the script, preview exported CSV files, and later check the database output.
#
# ---
#
# ## Architecture
#
# The Python script works like a human user using the SkillSelect dashboard:
#
# 1. Open the SkillSelect public dashboard
# 2. Navigate to the EOI Parameters page
# 3. Select two additional columns using the Yes/No tiles
# 4. Click NEXT to open the Results Table
# 5. Right-click the table and export the data as CSV
# 6. Save the downloaded CSV file
# 7. Repeat the same process for each selected column pair
# 8. Later, transform the CSV files and load them into SQLite for analysis
#
# In simple terms:
#
# **Open website → select columns → go to results → right-click export → save CSV → repeat → prepare for database loading**
#
# ---
#
# ## Run cells in this order
#
# ### 1. Setup
# Install and check the required Python packages.
#
# Main packages used:
# - `playwright`
# - `pandas`
# - `sqlite3` / SQLite
# - `pathlib`
#
# ---
#
# ### 2. Export CSVs
# Run the Playwright automation script.
#
# This script opens the browser, clicks through the SkillSelect dashboard, selects the required column pairs, exports the results table as CSV, and saves the files into:
#
# `raw_data/skillselect_exports`
#
# The script uses text and role-based locators where possible instead of relying on Qlik CSS classes, because Qlik class names are dynamic and can change.
#
# ---
#
# ### 3. Preview
# Check the exported CSV files.
#
# This step confirms that:
# - the files were downloaded successfully
# - the columns look correct
# - the data can be opened with pandas
# - the exported files are ready for transformation
#
# ---
#
# ### 4. ETL
# Transform the exported CSV files into a cleaner structure for database use.
#
# The expected process is:
#
# **CSV files → cleaned tables → long-format structure → load into SQLite**
#
# This step prepares the data for analysis and dashboard development.
#
# ---
#
# ### 5. Verify
# Check the final database output.
#
# This step confirms that:
# - data has been loaded correctly
# - row counts are reasonable
# - key fields are available
# - the database is ready for reporting and analysis

# %% [markdown]
# ## Cell 1 — Install dependencies
#
# This cell installs the Python packages required for the SkillSelect ETL workflow.
#
# It installs:
# - `playwright` for browser automation
# - `pandas` for reading and checking CSV files
# - `sqlalchemy` for future database connection support
# - `openpyxl` for Excel compatibility if needed later
#
# This cell only needs to be run when setting up the environment for the first time, or when using a new Python/Anaconda environment.

# %%
import subprocess, sys

packages = ['playwright', 'pandas', 'sqlalchemy', 'openpyxl']

for pkg in packages:
    subprocess.run([sys.executable, '-m', 'pip', 'install', pkg, '-q'], check=True)

subprocess.run([sys.executable, '-m', 'playwright', 'install', 'chromium'], check=True)

print('✅ All packages installed')
# Out:
# ✅ All packages installed

# %% [markdown]
# ## Cell 2 — Run SkillSelect CSV export
#
# This cell runs the main SkillSelect exporter script:
#
# `ETL/skillselect_csv_exporter.py`
#
# The script uses Playwright to automate the public SkillSelect dashboard.
#
# It works like a human user:
# 1. Opens the SkillSelect dashboard
# 2. Goes to the EOI Parameters page
# 3. Selects two additional column tiles
# 4. Clicks NEXT to open the Results Table
# 5. Right-clicks the results table
# 6. Selects the export/download option
# 7. Saves the CSV file
# 8. Repeats the same process for all selected column pairs
#
# This cell runs all 7 selected column-pair exports.

# %%
# %cd ~/Documents/Gov_ETL_data
# !python ETL/skillselect_csv_exporter.py --pairs 1 2 3 4 5 6 7
# Out:
# 🚀 Opening SkillSelect...
# ✅ Page loaded
#
# [1/7] Occupations × Points
#     [select] 'Visa Type' → '189'
#   ❌ Occupations×Points: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# [2/7] Occupations × English Test Score
#     [select] 'Visa Type' → '189'
#   ❌ Occupations×English Test Score: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# [3/7] Occupations × Nominated State
#     [select] 'Visa Type' → '189'
#   ❌ Occupations×Nominated State: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# [4/7] Points × English Test Score
#     [select] 'Visa Type' → '189'
#   ❌ Points×English Test Score: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# [5/7] Occupations × Australian Study
#     [select] 'Visa Type' → '189'
#   ❌ Occupations×Australian Study: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# [6/7] Occupations × Occupation Groups
#     [select] 'Visa Type' → '189'
#   ❌ Occupations×Occupation Groups: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# [7/7] Occupations × Regional Study
#     [select] 'Visa Type' → '189'
#   ❌ Occupations×Regional Study: Locator.wait_for: Timeout 10000ms exceeded.
# Call log:
#   - waiting for get_by_text("Visa Type").first to be visible
#     24 × locator resolved to hidden <a class="qcmd" data-qcmd="navClick" data-pagesource="https://api.dynamic.reports.employment.gov.au/anonap/single/?appid=aaac76b5-ad30-477e-9ca0-472f8ab57fc8&sheet=1fbfd90f-e36c-44b9-a078-a7c78a46792c&opt=ctxmenu">Dashboard Results Table: EOI by Visa Type and Sta…</a>
#
#
# ==================================================
# ✅ 0 exported  |  ❌ 7 failed
# Failed: [('Occupations_Points', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa'), ('Occupations_English', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa'), ('Occupations_State', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa'), ('Points_English', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa'), ('Occupations_AustralianStudy', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa'), ('Occupations_Groups', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa'), ('Occupations_RegionalStudy', 'Locator.wait_for: Timeout 10000ms exceeded.\nCall log:\n  - wa')]

# %% [markdown]
# ## Cell 3 — Check exported files
#
# This cell lists all CSV files saved in the SkillSelect export folder.
#
# The purpose is to confirm that the export process created the expected files.
#
# Expected folder:
#
# `raw_data/skillselect_exports`
#
# If the export worked correctly, this folder should contain CSV files for the selected SkillSelect column pairs.

# %%
# !find raw_data/skillselect_exports -type f | sort

# %% [markdown]
# ## Cell 4 — Preview exported CSV files
#
# This cell opens each exported CSV file using pandas.
#
# It shows:
# - the file name
# - the number of rows and columns
# - the first few rows of data
#
# This helps confirm that the CSV files were downloaded correctly and can be used for the next ETL step.

# %%
import pandas as pd
from pathlib import Path

files = sorted(Path("raw_data/skillselect_exports").glob("*.csv"))

for f in files:
    df = pd.read_csv(f)
    print("\n" + "="*80)
    print(f.name)
    print("Shape:", df.shape)
    display(df.head())

# %% [markdown]
# ## Cell 5 — Basic data quality check
#
# This cell performs a simple quality check on the exported CSV files.
#
# It checks:
# - column names
# - number of rows
# - missing values
# - whether each file can be read successfully
#
# This is not the full ETL process yet. It is a quick validation step before transforming and loading the data into SQLite.

# %%
for f in files:
    df = pd.read_csv(f)

    print("\n" + "="*80)
    print(f.name)
    print("Rows:", len(df))
    print("Columns:", list(df.columns))
    print("\nMissing values:")
    print(df.isna().sum())

# %% [markdown]
# ## Cell 6 — Monthly SkillSelect refresh
#
# ใช้รันเมื่อต้องการ refresh ข้อมูล เช่น รายเดือน
#
# Run this cell when the SkillSelect data needs to be refreshed.
#
# This command runs all 7 selected SkillSelect column-pair exports and saves the CSV files into:
#
# `raw_data/skillselect_exports`
#
# This is currently a manual monthly refresh process. It can be converted into an automatic scheduled ETL job later after the MySQL loading script has been completed and tested.

# %%
# %cd ~/Documents/Gov_ETL_data
# !python ETL/skillselect_csv_exporter.py --pairs 1 2 3 4 5 6 7
# Out:
# /Users/nattawitrasaengcha/Documents/Gov_ETL_data
#
# 🚀 Opening SkillSelect...
#    Debug screenshots → /Users/nattawitrasaengcha/Documents/Gov_ETL_data/raw_data/skillselect_debug
#     📸 161524_00_page_loaded.png
# ✅ Page loaded (Dashboard Overview)
#     → Navigating: Dashboard Overview → EOI Parameters
#     📸 161524_before_NEXT.png
#     📸 161526_after_NEXT.png
#     📸 161528_01_eoi_params_ready.png
#     ✅ On EOI Parameters (iframe confirmed)
#
# ──────────────────────────────────────────────────
# [1/7] Occupations + Points
# ──────────────────────────────────────────────────
#     → Tile: 'Occupations' → click 'Yes'
#     → Tile: 'Points' → click 'Yes'
#     📸 161531_01_columns_set_Occupations_Points.png
#     → Clicking NEXT...
#     📸 161531_before_NEXT.png
#     📸 161533_after_NEXT.png
#     📸 161535_01_after_next_Occupations_Points.png
#     → Exporting CSV...
#     📸 161535_before_Export.png
#     📸 161537_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 161738_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Occupations_Points.csv
#     → Back on EOI Parameters ✅
#     → Deselecting tiles: 'Occupations', 'Points'
#     → Tile: 'Occupations' → click 'No'
#     → Tile: 'Points' → click 'No'
#
# ──────────────────────────────────────────────────
# [2/7] Occupations + English Test Score
# ──────────────────────────────────────────────────
#     → Tile: 'Occupations' → click 'Yes'
#     → Tile: 'English Test Score' → click 'Yes'
#     📸 161756_02_columns_set_Occupations_English.png
#     → Clicking NEXT...
#     📸 161756_before_NEXT.png
#     📸 161758_after_NEXT.png
#     📸 161800_02_after_next_Occupations_English.png
#     → Exporting CSV...
#     📸 161800_before_Export.png
#     📸 161802_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 162004_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Occupations_English.csv
#     → Back on EOI Parameters ✅
#     → Deselecting tiles: 'Occupations', 'English Test Score'
#     → Tile: 'Occupations' → click 'No'
#     → Tile: 'English Test Score' → click 'No'
#
# ──────────────────────────────────────────────────
# [3/7] Occupations + Nominated State
# ──────────────────────────────────────────────────
#     → Tile: 'Occupations' → click 'Yes'
#     → Tile: 'Nominated State' → click 'Yes'
#     📸 162022_03_columns_set_Occupations_State.png
#     → Clicking NEXT...
#     📸 162022_before_NEXT.png
#     📸 162024_after_NEXT.png
#     📸 162026_03_after_next_Occupations_State.png
#     → Exporting CSV...
#     📸 162027_before_Export.png
#     📸 162028_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 162229_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Occupations_State.csv
#     → Back on EOI Parameters ✅
#     → Deselecting tiles: 'Occupations', 'Nominated State'
#     → Tile: 'Occupations' → click 'No'
#     → Tile: 'Nominated State' → click 'No'
#
# ──────────────────────────────────────────────────
# [4/7] Occupations + Occupation Groups
# ──────────────────────────────────────────────────
#     → Tile: 'Occupations' → click 'Yes'
#     → Tile: 'Occupation Groups' → click 'Yes'
#     📸 162247_04_columns_set_Occupations_Groups.png
#     → Clicking NEXT...
#     📸 162247_before_NEXT.png
#     📸 162249_after_NEXT.png
#     📸 162252_04_after_next_Occupations_Groups.png
#     → Exporting CSV...
#     📸 162252_before_Export.png
#     📸 162253_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 162454_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Occupations_Groups.csv
#     → Back on EOI Parameters ✅
#     → Deselecting tiles: 'Occupations', 'Occupation Groups'
#     → Tile: 'Occupations' → click 'No'
#     → Tile: 'Occupation Groups' → click 'No'
#
# ──────────────────────────────────────────────────
# [5/7] Points + English Test Score
# ──────────────────────────────────────────────────
#     → Tile: 'Points' → click 'Yes'
#     → Tile: 'English Test Score' → click 'Yes'
#     📸 162512_05_columns_set_Points_English.png
#     → Clicking NEXT...
#     📸 162512_before_NEXT.png
#     📸 162514_after_NEXT.png
#     📸 162517_05_after_next_Points_English.png
#     → Exporting CSV...
#     📸 162517_before_Export.png
#     📸 162518_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 162719_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Points_English.csv
#     → Back on EOI Parameters ✅
#     → Deselecting tiles: 'Points', 'English Test Score'
#     → Tile: 'Points' → click 'No'
#     → Tile: 'English Test Score' → click 'No'
#
# ──────────────────────────────────────────────────
# [6/7] Occupations + Australian Study
# ──────────────────────────────────────────────────
#     → Tile: 'Occupations' → click 'Yes'
#     → Tile: 'Australian Study' → click 'Yes'
#     📸 162737_06_columns_set_Occupations_AustralianStudy.png
#     → Clicking NEXT...
#     📸 162737_before_NEXT.png
#     📸 162740_after_NEXT.png
#     📸 162742_06_after_next_Occupations_AustralianStudy.png
#     → Exporting CSV...
#     📸 162742_before_Export.png
#     📸 162744_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 162945_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Occupations_AustralianStudy.csv
#     → Back on EOI Parameters ✅
#     → Deselecting tiles: 'Occupations', 'Australian Study'
#     → Tile: 'Occupations' → click 'No'
#     → Tile: 'Australian Study' → click 'No'
#
# ──────────────────────────────────────────────────
# [7/7] Occupations + Regional Study
# ──────────────────────────────────────────────────
#     → Tile: 'Occupations' → click 'Yes'
#     → Tile: 'Regional Study' → click 'Yes'
#     📸 163003_07_columns_set_Occupations_RegionalStudy.png
#     → Clicking NEXT...
#     📸 163003_before_NEXT.png
#     📸 163006_after_NEXT.png
#     📸 163008_07_after_next_Occupations_RegionalStudy.png
#     → Exporting CSV...
#     📸 163008_before_Export.png
#     📸 163010_after_right_click_table.png
#     → Clicking export menu item: Export data
#     → Clicking export menu item: Export
#     → Clicking export menu item: Export
#     → Clicking export menu item: Download
#     → Clicking export menu item: Download
#     📸 163212_after_Export_download.png
#     ✅ Saved: latest_189_Submitted_Occupations_RegionalStudy.csv
#     → Back on EOI Parameters ✅
#
# ==================================================
# EXPORT SUMMARY
# ==================================================
# ✅ Success: 7
# ❌ Failed:  0
#    ✅ Occupations+Points
#    ✅ Occupations+English Test Score
#    ✅ Occupations+Nominated State
#    ✅ Occupations+Occupation Groups
#    ✅ Points+English Test Score
#    ✅ Occupations+Australian Study
#    ✅ Occupations+Regional Study
#
# Files in: /Users/nattawitrasaengcha/Documents/Gov_ETL_data/raw_data/skillselect_exports

# %% [markdown]
# # Cell 6 — Future ETL to SQLite
#
# This section will be used later to transform the exported SkillSelect CSV files and load them into a SQLite database.
#
# Planned ETL process:
#
# 1. Read all exported CSV files
# 2. Clean column names and data types
# 3. Standardise values such as dates, visa types, EOI status, and count fields
# 4. Convert the files into a database-ready structure
# 5. Load the cleaned data into SQLite
# 6. Verify row counts and table structure
#
# This cell is a placeholder for the next stage of the project.
